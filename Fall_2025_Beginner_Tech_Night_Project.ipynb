# %%
def fight_sequence():
    food = inventory.get('food')
    weapon = inventory.get('weapon')
    player_health = 7

    if food == 'apples':
      player_health -= 1
    if weapon == 'shield':
      player_health += 2

    enemy_health = 8

    print("You decide to fight back.")

    while player_health > 0 and enemy_health > 0:
        print()
        print("Your Health:", player_health)
        print("Enemy Health:", enemy_health)

        method = input("Choose your attack method: JAB, UPPERCUT, KICK ")

        if method.lower() == "jab" and weapon == 'sword':
            print()
            print("POW! You jab at your opponent. 4 damage dealt. ")
            player_damage = 4
            enemy_health -= player_damage
            input("Press ENTER to continue. ")
        elif method.lower() == "jab" and weapon != 'sword':
            print()
            print("POW! You jab at your opponent. 3 damage dealt. ")
            player_damage = 3
            enemy_health -= player_damage
            input("Press ENTER to continue. ")

        elif method.lower() == "uppercut" and weapon == 'sword':
            print()
            print("SMACK! You hit your opponent with an uppercut. 5 damage dealt. ")
            player_damage = 5
            enemy_health -= player_damage
            input("Press ENTER to continue. ")

        elif method.lower() == "uppercut" and weapon != 'sword':
            print()
            print("SMACK! You hit your opponent with an uppercut. 4 damage dealt. ")
            player_damage = 4
            enemy_health -= player_damage
            input("Press ENTER to continue. ")

        elif method.lower() == "kick" and weapon == 'sword':
            print()
            print("WHAM! You kick your opponent. 4 damage dealt. ")
            player_damage = 4
            enemy_health -= player_damage
            input("Press ENTER to continue. ")

        elif method.lower() == "kick" and weapon != 'sword':
            print()
            print("WHAM! You kick your opponent. 3 damage dealt. ")
            player_damage = 3
            enemy_health -= player_damage
            input("Press ENTER to continue. ")

        if enemy_health > 0:
            print("\nBAM! Your opponent hits back, dealing 3 damage.")
            player_health -= 3


    if player_health <= 0:
          print("\nTHE END: You taste bitter defeat at the hands of your opponent.")
          print("Try again to see if you can escape the island.")
          return True #  lost
    else:
        print("\nCongratulations! You emerge victorious.")
        return False #   won

print("ESCAPE FROM THE LOST SHORE: A Text-Based Adventure")
input("Press ENTER to play. ")
print("You find yourself stranded on an island. All you can hear is the wind and the waves.")
name = input("What is your name?: ")
print(f"Welcome {name}")
print("You don't remember how you got here, but you know you want to find a way to get home. ")
inventory = {} # inventory dictionary

print()
print("You see a crate nearby. Do you wish to open it?")
crate = input("YES or NO? ")
if crate.lower() == "no":
  inventory['food'] = None
  print("You walk away.")
elif crate.lower() == "yes":
  inventory['food'] = "apples" # 'food' key created, 'apples' assigned as value
  print("You get some apples and decide to eat one.")
  input("Press ENTER to continue.")
  print("Taking a bite, you immediately feel dizzy.")
  print("\x1B[3mPlayer Health -1\x1B[0m")
  input("Press ENTER to continue.")

print()
print("Behind you is a forest. You hear something chittering inside.")
print("In front of you is the coastline. You think you can see something sparkling in the water.")

place1 = input("Do you want to go to the FOREST or the COAST first? ")

while place1.lower() != "forest" and place1.lower() != "coast":
  print("Incorrect choice. Try again.")
  place1 = input("Do you want to go to the FOREST or the COAST first? ")


if place1.lower() == "forest":
      print()
      print("You find youself drawn to the lush forest behind you and decide to explore. On the way, you trip on something on the ground.")
      input("Press ENTER to continue.")
      print()
      print("It's appears to be a shield and a sword, left by a knight long ago.")
      print("Maybe they can help you on the island. ")
      weapon_choice = input("Take the SHIELD or SWORD? ")
      while weapon_choice.lower() != "shield" and weapon_choice.lower() != "sword":
        print("Incorrect choice. Try again. ")
        weapon_choice = input("Take the SHIELD or SWORD? ")
      if weapon_choice.lower() == "shield":
        inventory['weapon'] = 'shield'
        print("\x1B[3mPlayer Health +2!\x1B[0m")
      if weapon_choice.lower() == 'sword':
        inventory['weapon'] = 'sword'
        print("\x1B[3mPlayer Attacks +1\x1B[0m")
      print("Good choice!")
      print()
      print("All of a sudden, you hear a loud voice echoing from the trees.")
      print("\x1B[3mWho enters into the forest?\x1B[0m")
      input("Press ENTER to continue.")
      print("A tall, branch-like monster drops down in front of you and swings at your face. ")
      player_lost = fight_sequence()
      if player_lost:
          exit()
      print()
      print("With it's last breath, the monster mutters: ")
      print("\x1B[3mIf you want to escape, remember the PEARL\x1B[0m")
      print("This may be important later.")
      input("Press ENTER to continue.")
      print()
      print("You return to the sandy beach where you started off and make your way down the coastline.")
      print("On the shore you see a small figure rapidly approaching, cloaked in a dark hood.")
      action1 = input("Would you like to SPEAK to the figure or FIGHT it? ")

      while action1.lower() != "speak" and action1.lower() != "fight":
        print("Incorrect choice. Try again. ")
        action1 = input("Would you like to SPEAK to the figure or FIGHT it? ")

      if action1.lower() == "speak":
        print()
        print("\x1B[3mHEY YOU! What are you doing here?\x1B[0m")
        input("Press ENTER to continue.")
        print("\nThe figure seems to be gearing up for an attack.")
        player_lost = fight_sequence()
        if player_lost:
          exit()

      elif action1.lower() == "fight":
        player_lost = fight_sequence()
        if player_lost:
          exit()
      print("In defeat, the figure offers you a riddle: ")
      input("Press ENTER to continue.")
      print("\n\x1B[3mIf free is what you wish to be\x1B[0m")
      print("\x1B[3mFollow the dying light to the golden key\x1B[0m")
      print()




elif place1.lower() == "coast":
      print()
      print("The tantalizing water draws you in, and you decide to explore the coastline. On the sandy shore, you foot hits something solid.")
      print()
      print("It's appears to be a shield and a sword, left by a knight long ago.")
      print("Maybe they can help you on the island. ")
      print("Unforunately, you only have the strength to carry one.")
      weapon_choice = input("Take the SHIELD or SWORD? ")
      while weapon_choice.lower() != "shield" and weapon_choice.lower() != "sword":
        print("Incorrect choice. Try again. ")
        weapon_choice = input("Take the SHIELD or SWORD? ")
      if weapon_choice.lower() == "shield":
        inventory['weapon'] = 'shield'
        print("\x1B[3mPlayer Health +2!\x1B[0m")
      elif weapon_choice.lower() == 'sword':
        inventory['weapon'] = 'sword'
        print("\x1B[3mPlayer Attacks +1\x1B[0m")
      input("Press ENTER to continue.")
      print("On the shore you see a small figure rapidly approaching, cloaked in a dark hood.")
      action1 = input("Would you like to SPEAK to the figure or FIGHT it? ")

      while action1.lower() != "speak" and action1.lower() != "fight":
        print("Incorrect choice. Try again. ")
        action1 = input("Would you like to SPEAK to the figure or FIGHT it? ")

      if action1.lower() == "speak":
        print()
        print("\x1B[3mHEY YOU! What are you doing here?\x1B[0m")
        input("Press ENTER to continue.")
        print("\nThe figure seems to be gearing up for an attack.")
        player_lost = fight_sequence()
        if player_lost:
          exit()

      elif action1.lower() == "fight":
        player_lost = fight_sequence()
        if player_lost:
          exit()

      print("In defeat, the figure offers you a riddle: ")
      input("Press ENTER to continue.")
      print("\n\x1B[3mIf free is what you wish to be\x1B[0m")
      print("\x1B[3mFollow the dying light to the golden key\x1B[0m")
      print()
      input("Press ENTER to continue.")
      print("You return to the sandy beach where you started off and make your way into the forest.")
      input("Press ENTER to continue.")
      print()
      print("All of a sudden, you hear a loud voice echoing from the trees.")
      print("\x1B[3mWho enters into the forest?\x1B[0m")
      input("Press ENTER to continue.")
      print("A tall, branch-like monster drops down in front of you and swings at your face. ")
      player_lost = fight_sequence()
      if player_lost:
          exit()
      input("Press ENTER to continue.")
      print()
      print("With it's last breath, the monster mutters")
      print("\x1B[3mIf you want to escape, remember the PEARL\x1B[0m")
      print("This may be important later.")



input("Press ENTER to continue.")
print("In the distance, the sun begins to set.")
input("Press ENTER to continue.")
print("You know deep down that this is your last chance to escape your fate on the island.")
input("Press ENTER to continue.")
final_choice = input("SWIM towards the sunset or DIG through the sand? ")

if final_choice.lower() == "swim":
      print()
      print("You kick off from the beach, gliding through the water towards the red sun in the distance.")
      input("Press ENTER to continue.")
      print("You feel at peace, and your vision begins to blur.")
      input("Press ENTER to continue.")
      pw = input("Your final test: What is the secret of the island? ")
      count = 1
      while pw.lower() != "pearl" and count < 3:
          print()
          print("That's not right. Try again, or remain trapped forever.")
          pw = input("Your final test: What is the secret of the island? ")
          count += 1
      if pw.lower() == "pearl":
          print(f"You hear a soft voice...{name}...WAKE UP.")
          input("Press ENTER to continue.")
          print("Finally, you wake up from this nightmarish dream, safe in your own bed.")
          input("Press ENTER to continue.")
          print("THE END: Congratulations! You successfully escaped and now return to your normal life.")
      else:
          print("You have not learned the secret of the island.")
          print("THE END: You are doomed to roam the sandy shores forever.")
          exit()


elif final_choice.lower() == "dig":
      print()
      print("Clawing at the ground, you begin to push the sand away beneath you.")
      input("Press ENTER to continue.")
      print("All of a sudden, the sand falls away and you tumble into an endless void, doomed.")
      input("Press ENTER to continue.")
      print("THE END: You remain in the void under the island, unable to escape. ")
      exit()
# Out:
# ESCAPE FROM THE LOST SHORE: A Text-Based Adventure
